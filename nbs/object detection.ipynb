# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
from fastai.conv_learner import *
from fastai.dataset import *

from pathlib import Path
import json
from PIL import ImageDraw, ImageFont
from matplotlib import patches, patheffects

# %%
# Code taken from https://github.com/mutaku/xml2json

import xml.etree.cElementTree as ET
import simplejson, optparse, sys, os

def elem_to_internal(elem,strip=1):

    """Convert an Element into an internal dictionary (not JSON!)."""

    d = {}
    for key, value in elem.attrib.items():
        d['@'+key] = value

    # loop over subelements to merge them
    for subelem in elem:
        v = elem_to_internal(subelem,strip=strip)
        tag = subelem.tag
        value = v[tag]
        try:
            # add to existing list for this tag
            d[tag].append(value)
        except AttributeError:
            # turn existing entry into a list
            d[tag] = [d[tag], value]
        except KeyError:
            # add a new non-list entry
            d[tag] = value
    text = elem.text
    tail = elem.tail
    if strip:
        # ignore leading and trailing whitespace
        if text: text = text.strip()
        if tail: tail = tail.strip()

    if tail:
        d['#tail'] = tail

    if d:
        # use #text element if other attributes exist
        if text: d["#text"] = text
    else:
        # text is the value if no attributes
        d = text or None
    return {elem.tag: d}

def elem2json(elem, strip=1):

    """Convert an ElementTree or Element into a JSON string."""

    if hasattr(elem, 'getroot'):
        elem = elem.getroot()
    return simplejson.dumps(elem_to_internal(elem,strip=strip))

def xml2json(xmlstring,strip=1):

    """Convert an XML string into a JSON string."""

    elem = ET.fromstring(xmlstring)
    return elem2json(elem,strip=strip)

# %%
PATH = Path('/home/paperspace/fastai/nba_court_vision/data/annotations')

# %%
annotations = [json.loads(xml2json(open(f).read()))['annotation'] for f in PATH.iterdir()]

# %%
len(annotations)
# Out:
# 131

# %%
PATH = Path('/home/paperspace/data/pascal')
trn_j = json.load((PATH / 'pascal_train2007.json').open())
IMAGES,ANNOTATIONS,CATEGORIES = ['images', 'annotations', 'categories']
FILE_NAME,ID,IMG_ID,CAT_ID,BBOX = 'file_name','id','image_id','category_id','bbox'

cats = dict((o[ID], o['name']) for o in trn_j[CATEGORIES])
trn_fns = dict((o[ID], o[FILE_NAME]) for o in trn_j[IMAGES])
trn_ids = [o[ID] for o in trn_j[IMAGES]]

JPEGS = 'VOCdevkit/VOC2007/JPEGImages'
IMG_PATH = PATH/JPEGS

# %%
PATH = Path('/home/paperspace/fastai/data/team')

# %%
output = []
for annot in annotations:
    a_obj = annot['object']
    bb_dicts = [a['bndbox'] for a in a_obj]
    o = a_obj[0]

    bs = [[int(a['xmin']), 
           int(a['ymin']), 
           int(a['xmax'])-int(a['xmin']), 
           int(a['ymax'])-int(a['ymin'])
          ] for a in bb_dicts]

    cats = [a['name'] for a in a_obj]
    area = [b[2]*b[3] for b in bs]
    fn = [str(PATH/annot['filename'])] * len(bs)

    for a, b, c, f in zip(area, bs, cats, fn):
        output.append({'area':a, 'bbox':b, 'category_id':c, 'id':f})

# %%
pickle.dump(output, open('annotations_list.pkl','wb'))

# %%
cat2idx = {'player':0, 'hoop':1, 'ft':2, 'ball':3, 'clogo':4}
idx2cat = {v:k for k,v in cat2idx.items()}

# %%
output
# Out:
# [{'area': 6840,
#   'bbox': [819, 347, 57, 120],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bulls_bucks_h1_1.jpg'},
#  {'area':

#   'category_id': 'ball',
#   'id': '/home/paperspace/fastai/data/team/cavs_bucks_h2_3.jpg'},
#  {'area': 3752,
#   'bbox': [794, 243, 56, 67],
#   'category_id': 'hoop',
#   'id': '/home/paperspace/fastai/data/team/cavs_bucks_h2_3.jpg'},
#  {'area': 14948,
#   'bbox': [976, 341, 74, 202],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_bucks_h2_3.jpg'},
#  {'area': 14628,
#   'bbox': [909, 368, 69, 212],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_bucks_h2_3.jpg'},
#  {'area': 18778,
#   'bbox': [807, 385, 82, 229],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_bucks_h2_3.jpg'},
#  {'area': 15111,
#   'bbox': [688, 414, 73, 207],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_bucks_h2_3.jpg'},
#  {'area': 14742,
#   'bbox': [1141, 278, 81, 182],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_bucks_h2_3.jpg'},
#  {'area': 19550,
#   'bbox': [708, 470, 85, 230],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_bucks_h2_3.jpg'},
#  {'area': 44253,
#   'bbox': [360, 560, 149, 297],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_bucks_h2_3.jpg'},
#  {'area': 18942,
#   'bbox': [1249, 393, 82, 231],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_bucks_h2_3.jpg'},
#  {'area': 33394,
#   'bbox': [1589, 480, 118, 283],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_bucks_h2_3.jpg'},
#  {'area': 832,
#   'bbox': [867, 326, 32, 26],
#   'category_id': 'ball',
#   'id': '/home/paperspace/fastai/data/team/76ers_bulls_h2_0.jpg'},
#  {'area': 43740,
#   'bbox': [615, 638, 324, 135],
#   'category_id': 'ft',
#   'id': '/home/paperspace/fastai/data/team/76ers_bulls_h2_0.jpg'},
#  {'area': 4836,
#   'bbox': [1282, 284, 62, 78],
#   'category_id': 'hoop',
#   'id': '/home/paperspace/fastai/data/team/76ers_bulls_h2_0.jpg'},
#  {'area': 12994,
#   'bbox': [1189, 488, 73, 178],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_bulls_h2_0.jpg'},
#  {'area': 18042,
#   'bbox': [1217, 534, 97, 186],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_bulls_h2_0.jpg'},
#  {'area': 22278,
#   'bbox': [1198, 552, 94, 237],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_bulls_h2_0.jpg'},
#  {'area': 26600,
#   'bbox': [1182, 706, 100, 266],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_bulls_h2_0.jpg'},
#  {'area': 20000,
#   'bbox': [1544, 535, 100, 200],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_bulls_h2_0.jpg'},
#  {'area': 20962,
#   'bbox': [1381, 472, 94, 223],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_bulls_h2_0.jpg'},
#  {'area': 27886,
#   'bbox': [809, 406, 146, 191],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_bulls_h2_0.jpg'},
#  {'area': 19404,
#   'bbox': [1009, 356, 99, 196],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_bulls_h2_0.jpg'},
#  {'area': 17052,
#   'bbox': [743, 361, 84, 203],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_bulls_h2_0.jpg'},
#  {'area': 16732,
#   'bbox': [879, 265, 89, 188],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_bulls_h2_0.jpg'},
#  {'area': 37008,
#   'bbox': [1305, 298, 144, 257],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_pistons_h2_1.jpg'},
#  {'area': 26460,
#   'bbox': [1199, 211, 126, 210],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_pistons_h2_1.jpg'},
#  {'area': 22572,
#   'bbox': [1125, 286, 114, 198],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_pistons_h2_1.jpg'},
#  {'area': 21837,
#   'bbox': [1175, 388, 87, 251],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_pistons_h2_1.jpg'},
#  {'area': 28840,
#   'bbox': [805, 386, 103, 280],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_pistons_h2_1.jpg'},
#  {'area': 17864,
#   'bbox': [898, 240, 77, 232],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_pistons_h2_1.jpg'},
#  {'area': 15990,
#   'bbox': [849, 102, 82, 195],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_pistons_h2_1.jpg'},
#  {'area': 23822,
#   'bbox': [593, 200, 86, 277],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_pistons_h2_1.jpg'},
#  {'area': 16236,
#   'bbox': [620, 119, 66, 246],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_pistons_h2_1.jpg'},
#  {'area': 1280,
#   'bbox': [1191, 244, 32, 40],
#   'category_id': 'ball',
#   'id': '/home/paperspace/fastai/data/team/blazers_pistons_h2_1.jpg'},
#  {'area': 5376,
#   'bbox': [504, 125, 64, 84],
#   'category_id': 'hoop',
#   'id': '/home/paperspace/fastai/data/team/blazers_pistons_h2_1.jpg'},
#  {'area': 60660,
#   'bbox': [1003, 502, 337, 180],
#   'category_id': 'ft',
#   'id': '/home/paperspace/fastai/data/team/blazers_pistons_h2_1.jpg'},
#  {'area': 891,
#   'bbox': [912, 378, 27, 33],
#   'category_id': 'ball',
#   'id': '/home/paperspace/fastai/data/team/76ers_blazers_h2_0.jpg'},
#  {'area': 22900,
#   'bbox': [1294, 416, 100, 229],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_blazers_h2_0.jpg'},
#  {'area': 20116,
#   'bbox': [1268, 571, 107, 188],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_blazers_h2_0.jpg'},
#  {'area': 17220,
#   'bbox': [956, 412, 82, 210],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_blazers_h2_0.jpg'},
#  {'area': 13632,
#   'bbox': [909, 357, 71, 192],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_blazers_h2_0.jpg'},
#  {'area': 8325,
#   'bbox': [923, 331, 45, 185],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_blazers_h2_0.jpg'},
#  {'area': 17328,
#   'bbox': [1442, 397, 76, 228],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_blazers_h2_0.jpg'},
#  {'area': 11323,
#   'bbox': [1367, 292, 67, 169],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_blazers_h2_0.jpg'},
#  {'area': 20592,
#   'bbox': [734, 521, 88, 234],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_blazers_h2_0.jpg'},
#  {'area': 15244,
#   'bbox': [712, 446, 74, 206],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_blazers_h2_0.jpg'},
#  {'area': 35090,
#   'bbox': [1205, 538, 290, 121],
#   'category_id': 'ft',
#   'id': '/home/paperspace/fastai/data/team/76ers_blazers_h2_0.jpg'},
#  {'area': 4221,
#   'bbox': [827, 229, 67, 63],
#   'category_id': 'hoop',
#   'id': '/home/paperspace/fastai/data/team/76ers_blazers_h2_0.jpg'},
#  {'area': 9999,
#   'bbox': [1085, 341, 99, 101],
#   'category_id': 'ball',
#   'id': '/home/paperspace/fastai/data/team/76ers_grizzlies_h1_1.jpg'},
#  {'area': 29359,
#   'bbox': [1101, 155, 187, 157],
#   'category_id': 'hoop',
#   'id': '/home/paperspace/fastai/data/team/76ers_grizzlies_h1_1.jpg'},
#  {'area': 40480,
#   'bbox': [571, 681, 160, 253],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_grizzlies_h1_1.jpg'},
#  {'area': 35872,
#   'bbox': [724, 633, 118, 304],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_grizzlies_h1_1.jpg'},
#  {'area': 261855,
#   'bbox': [927, 179, 345, 759],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_grizzlies_h1_1.jpg'},
#  {'area': 61380,
#   'bbox': [1619, 596, 180, 341],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_grizzlies_h1_1.jpg'},
#  {'area': 82998,
#   'bbox': [1412, 624, 261, 318],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_grizzlies_h1_1.jpg'},
#  {'area': 1640,
#   'bbox': [1071, 589, 40, 41],
#   'category_id': 'ball',
#   'id': '/home/paperspace/fastai/data/team/bucks_pacers_h1_4.jpg'},
#  {'area': 20868,
#   'bbox': [770, 575, 94, 222],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bucks_pacers_h1_4.jpg'},
#  {'area': 11856,
#   'bbox': [682, 537, 114, 104],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bucks_pacers_h1_4.jpg'},
#  {'area': 21240,
#   'bbox': [958, 352, 90, 236],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bucks_pacers_h1_4.jpg'},
#  {'area': 15678,
#   'bbox': [875, 337, 67, 234],
#   'category_id': 'player',
# ...
#  {'area': 3692,
#   'bbox': [645, 239, 52, 71],
#   'category_id': 'hoop',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_3.jpg'},
#  {'area': 16554,
#   'bbox': [1528, 363, 93, 178],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_3.jpg'},
#  {'area': 13510,
#   'bbox': [1317, 361, 70, 193],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_3.jpg'},
#  {'area': 13760,
#   'bbox': [1281, 418, 64, 215],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_3.jpg'},
#  {'area': 26460,
#   'bbox': [1349, 429, 108, 245],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_3.jpg'},
#  {'area': 20340,
#   'bbox': [1482, 444, 90, 226],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_3.jpg'},
#  {'area': 21242,
#   'bbox': [1071, 417, 86, 247],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_3.jpg'},
#  {'area': 10830,
#   'bbox': [937, 298, 57, 190],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_3.jpg'},
#  {'area': 10106,
#   'bbox': [991, 279, 62, 163],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_3.jpg'},
#  {'area': 16128,
#   'bbox': [318, 505, 72, 224],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_3.jpg'},
#  {'area': 21320,
#   'bbox': [256, 508, 82, 260],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_3.jpg'},
#  {'area': 78676,
#   'bbox': [1440, 609, 356, 221],
#   'category_id': 'ft',
#   'id': '/home/paperspace/fastai/data/team/76ers_rockets_h2_4.jpg'},
#  {'area': 6474,
#   'bbox': [783, 180, 78, 83],
#   'category_id': 'hoop',
#   'id': '/home/paperspace/fastai/data/team/76ers_rockets_h2_4.jpg'},
#  {'area': 29667,
#   'bbox': [721, 336, 87, 341],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_rockets_h2_4.jpg'},
#  {'area': 34138,
#   'bbox': [635, 397, 101, 338],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_rockets_h2_4.jpg'},
#  {'area': 40392,
#   'bbox': [476, 396, 136, 297],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_rockets_h2_4.jpg'},
#  {'area': 44814,
#   'bbox': [929, 530, 291, 154],
#   'category_id': 'ft',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h2_0.jpg'},
#  {'area': 4977,
#   'bbox': [505, 221, 63, 79],
#   'category_id': 'hoop',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h2_0.jpg'},
#  {'area': 15624,
#   'bbox': [1166, 264, 72, 217],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h2_0.jpg'},
#  {'area': 14080,
#   'bbox': [1072, 277, 64, 220],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h2_0.jpg'},
#  {'area': 12675,
#   'bbox': [990, 230, 65, 195],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h2_0.jpg'},
#  {'area': 24220,
#   'bbox': [816, 318, 140, 173],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h2_0.jpg'},
#  {'area': 11136,
#   'bbox': [732, 213, 64, 174],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h2_0.jpg'},
#  {'area': 11385,
#   'bbox': [700, 311, 69, 165],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h2_0.jpg'},
#  {'area': 16800,
#   'bbox': [434, 406, 80, 210],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h2_0.jpg'},
#  {'area': 14705,
#   'bbox': [486, 387, 85, 173],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h2_0.jpg'},
#  {'area': 24600,
#   'bbox': [551, 436, 100, 246],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h2_0.jpg'},
#  {'area': 22200,
#   'bbox': [451, 575, 100, 222],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h2_0.jpg'},
#  {'area': 11904,
#   'bbox': [633, 363, 62, 192],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h1_1.jpg'},
#  {'area': 34304,
#   'bbox': [596, 668, 128, 268],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h1_1.jpg'},
#  {'area': 17355,
#   'bbox': [612, 495, 89, 195],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h1_1.jpg'},
#  {'area': 34974,
#   'bbox': [1025, 411, 134, 261],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h1_1.jpg'},
#  {'area': 28458,
#   'bbox': [1448, 422, 102, 279],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h1_1.jpg'},
#  {'area': 12816,
#   'bbox': [1481, 331, 72, 178],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h1_1.jpg'},
#  {'area': 13870,
#   'bbox': [1369, 344, 73, 190],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h1_1.jpg'},
#  {'area': 10890,
#   'bbox': [909, 246, 55, 198],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h1_1.jpg'},
#  {'area': 15549,
#   'bbox': [829, 323, 73, 213],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h1_1.jpg'},
#  {'area': 12036,
#   'bbox': [691, 329, 68, 177],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h1_1.jpg'},
#  {'area': 61149,
#   'bbox': [1010, 579, 327, 187],
#   'category_id': 'ft',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h1_1.jpg'},
#  {'area': 4536,
#   'bbox': [579, 258, 56, 81],
#   'category_id': 'hoop',
#   'id': '/home/paperspace/fastai/data/team/bucks_magic_h1_1.jpg'},
#  {'area': 47704,
#   'bbox': [1088, 567, 356, 134],
#   'category_id': 'ft',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_1.jpg'},
#  {'area': 5040,
#   'bbox': [731, 230, 63, 80],
#   'category_id': 'hoop',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_1.jpg'},
#  {'area': 17711,
#   'bbox': [1118, 313, 89, 199],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_1.jpg'},
#  {'area': 13452,
#   'bbox': [1039, 338, 76, 177],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_1.jpg'},
#  {'area': 24250,
#   'bbox': [1301, 404, 97, 250],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_1.jpg'},
#  {'area': 14118,
#   'bbox': [1386, 431, 78, 181],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_1.jpg'},
#  {'area': 38420,
#   'bbox': [1338, 485, 170, 226],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_1.jpg'},
#  {'area': 17220,
#   'bbox': [1107, 404, 84, 205],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_1.jpg'},
#  {'area': 15884,
#   'bbox': [553, 414, 76, 209],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_1.jpg'},
#  {'area': 27120,
#   'bbox': [721, 477, 113, 240],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_1.jpg'},
#  {'area': 21812,
#   'bbox': [584, 481, 76, 287],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_1.jpg'},
#  {'area': 31137,
#   'bbox': [202, 504, 107, 291],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_1.jpg'},
#  {'area': 68620,
#   'bbox': [1377, 698, 365, 188],
#   'category_id': 'ft',
#   'id': '/home/paperspace/fastai/data/team/76ers_rockets_h2_1.jpg'},
#  {'area': 7650,
#   'bbox': [699, 231, 85, 90],
#   'category_id': 'hoop',
#   'id': '/home/paperspace/fastai/data/team/76ers_rockets_h2_1.jpg'},
#  {'area': 25056,
#   'bbox': [1161, 392, 96, 261],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_rockets_h2_1.jpg'},
#  {'area': 31270,
#   'bbox': [1065, 312, 106, 295],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_rockets_h2_1.jpg'},
#  {'area': 20355,
#   'bbox': [1004, 373, 69, 295],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_rockets_h2_1.jpg'},
#  {'area': 33522,
#   'bbox': [1014, 445, 111, 302],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_rockets_h2_1.jpg'},
#  {'area': 37346,
#   'bbox': [671, 515, 142, 263],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_rockets_h2_1.jpg'},
#  {'area': 36708,
#   'bbox': [590, 466, 114, 322],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_rockets_h2_1.jpg'},
#  {'area': 26180,
#   'bbox': [1212, 237, 85, 308],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_rockets_h2_1.jpg'},
#  {'area': 35105,
#   'bbox': [647, 628, 119, 295],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_rockets_h2_1.jpg'},
#  {'area': 38843,
#   'bbox': [225, 723, 179, 217],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_rockets_h2_1.jpg'},
#  {'area': 9344,
#   'bbox': [1238, 387, 73, 128],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_76ers_h2_0.jpg'},
#  {'area': 4719,
#   'bbox': [1215, 368, 39, 121],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_76ers_h2_0.jpg'},
#  {'area': 5900,
#   'bbox': [1261, 313, 50, 118],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_76ers_h2_0.jpg'},
#  {'area': 11139,
#   'bbox': [1155, 466, 79, 141],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_76ers_h2_0.jpg'},
#  {'area': 6670,
#   'bbox': [1137, 388, 58, 115],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_76ers_h2_0.jpg'},
#  {'area': 4545,
#   'bbox': [1106, 316, 45, 101],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_76ers_h2_0.jpg'},
#  {'area': 5324,
#   'bbox': [1008, 350, 44, 121],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_76ers_h2_0.jpg'},
#  {'area': 8487,
#   'bbox': [908, 338, 69, 123],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_76ers_h2_0.jpg'},
#  {'area': 13430,
#   'bbox': [1067, 440, 170, 79],
#   'category_id': 'ft',
#   'id': '/home/paperspace/fastai/data/team/blazers_76ers_h2_0.jpg'},
#  {'area': 441,
#   'bbox': [1038, 523, 21, 21],
#   'category_id': 'ball',
#   'id': '/home/paperspace/fastai/data/team/blazers_76ers_h2_0.jpg'},
#  {'area': 1364,
#   'bbox': [1426, 262, 31, 44],
#   'category_id': 'hoop',
#   'id': '/home/paperspace/fastai/data/team/blazers_76ers_h2_0.jpg'},
#  {'area': 24840,
#   'bbox': [422, 337, 108, 230],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_2.jpg'},
#  {'area': 9520,
#   'bbox': [970, 312, 70, 136],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_2.jpg'},
#  {'area': 31218,
#   'bbox': [714, 408, 121, 258],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_2.jpg'},
#  {'area': 23856,
#   'bbox': [779, 359, 142, 168],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_2.jpg'},
#  {'area': 15200,
#   'bbox': [1002, 301, 95, 160],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_2.jpg'},
#  {'area': 16510,
#   'bbox': [1638, 438, 65, 254],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_2.jpg'},
#  {'area': 17355,
#   'bbox': [1355, 346, 89, 195],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_2.jpg'},
#  {'area': 24700,
#   'bbox': [1247, 408, 100, 247],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_2.jpg'},
#  {'area': 22320,
#   'bbox': [1034, 461, 80, 279],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_2.jpg'},
#  {'area': 33972,
#   'bbox': [258, 499, 114, 298],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_2.jpg'},
#  {'area': 3626,
#   'bbox': [1383, 212, 49, 74],
#   'category_id': 'hoop',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_2.jpg'},
#  {'area': 39345,
#   'bbox': [721, 533, 305, 129],
#   'category_id': 'ft',
#   'id': '/home/paperspace/fastai/data/team/cavs_celtics_h1_2.jpg'},
#  {'area': 1560,
#   'bbox': [1145, 577, 39, 40],
#   'category_id': 'ball',
#   'id': '/home/paperspace/fastai/data/team/blazers_pistons_h1_0.jpg'},
#  {'area': 22437,
#   'bbox': [1717, 522, 81, 277],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_pistons_h1_0.jpg'},
#  {'area': 31950,
#   'bbox': [1099, 111, 142, 225],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_pistons_h1_0.jpg'},
#  {'area': 39116,
#   'bbox': [1081, 435, 154, 254],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_pistons_h1_0.jpg'},
#  {'area': 46365,
#   'bbox': [800, 390, 165, 281],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_pistons_h1_0.jpg'},
#  {'area': 27280,
#   'bbox': [658, 331, 110, 248],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_pistons_h1_0.jpg'},
#  {'area': 29920,
#   'bbox': [1457, 85, 136, 220],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_pistons_h1_0.jpg'},
#  {'area': 52400,
#   'bbox': [1480, 258, 200, 262],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_pistons_h1_0.jpg'},
#  {'area': 3536,
#   'bbox': [1266, 197, 68, 52],
#   'category_id': 'clogo',
#   'id': '/home/paperspace/fastai/data/team/blazers_pistons_h1_0.jpg'},
#  {'area': 50690,
#   'bbox': [128, 414, 274, 185],
#   'category_id': 'ft',
#   'id': '/home/paperspace/fastai/data/team/blazers_pistons_h1_0.jpg'},
#  {'area': 38376,
#   'bbox': [435, 332, 156, 246],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/blazers_pistons_h1_0.jpg'},
#  {'area': 39396,
#   'bbox': [1433, 449, 147, 268],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_clippers_h1_4.jpg'},
#  {'area': 25064,
#   'bbox': [984, 389, 104, 241],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_clippers_h1_4.jpg'},
#  {'area': 24582,
#   'bbox': [918, 426, 102, 241],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_clippers_h1_4.jpg'},
#  {'area': 39894,
#   'bbox': [1020, 568, 122, 327],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_clippers_h1_4.jpg'},
#  {'area': 44080,
#   'bbox': [847, 474, 145, 304],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_clippers_h1_4.jpg'},
#  {'area': 22100,
#   'bbox': [792, 321, 68, 325],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_clippers_h1_4.jpg'},
#  {'area': 23958,
#   'bbox': [1080, 359, 99, 242],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_clippers_h1_4.jpg'},
#  {'area': 19620,
#   'bbox': [1118, 328, 90, 218],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_clippers_h1_4.jpg'},
#  {'area': 11514,
#   'bbox': [1171, 290, 57, 202],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/76ers_clippers_h1_4.jpg'},
#  {'area': 48100,
#   'bbox': [1389, 680, 260, 185],
#   'category_id': 'ft',
#   'id': '/home/paperspace/fastai/data/team/76ers_clippers_h1_4.jpg'},
#  {'area': 1209,
#   'bbox': [823, 292, 39, 31],
#   'category_id': 'ball',
#   'id': '/home/paperspace/fastai/data/team/76ers_clippers_h1_4.jpg'},
#  {'area': 5382,
#   'bbox': [829, 295, 69, 78],
#   'category_id': 'hoop',
#   'id': '/home/paperspace/fastai/data/team/76ers_clippers_h1_4.jpg'},
#  {'area': 27600,
#   'bbox': [1066, 458, 138, 200],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bulls_nets_h1_1.jpg'},
#  {'area': 27792,
#   'bbox': [1024, 530, 144, 193],
#   'category_id': 'player',
#   'id': '/home/paperspace/fastai/data/team/bulls_nets_h1_1.jpg'},
#  ...]

# %%
from collections import defaultdict
def hw_bb(bb): return np.array([bb[1], bb[0], bb[3]+bb[1]-1, bb[2]+bb[0]-1])
def bb_hw(a): return np.array([a[1],a[0],a[3]-a[1]+1,a[2]-a[0]+1])

# %%
trn_anno = collections.defaultdict(list)

# %%
for o in output:
    bb = hw_bb(o['bbox'])
    trn_anno[o['id']].append((bb, cat2idx[o['category_id']]))

# %%
def draw_rect(ax, b):
    patch = ax.add_patch(patches.Rectangle(b[:2], *b[-2:], fill=False, edgecolor='white', lw=2))
    draw_outline(patch, 4)

# %%
def show_img(im, figsize=None, ax=None):
    if not ax: fig,ax = plt.subplots(figsize=figsize)
    ax.imshow(im)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    return ax

# %%
def draw_outline(o, lw):
    o.set_path_effects([patheffects.Stroke(
        linewidth=lw, foreground='black'), patheffects.Normal()])

# %%
def get_lrg(b):
    if not b: raise Exception()
    b = sorted(b, key=lambda x: np.product(x[0][-2:] - x[0[:2]]), reverse=True)
    return b[0]

# %%
trn_lrg_ann = {a: get_lrg(b) for a,b in trn_anno.items()}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-fd997b2cabd9> in <module>()
# ----> 1 trn_lrg_ann = {a: get_lrg(b) for a,b in trn_anno.items()}
#
# <ipython-input-31-fd997b2cabd9> in <dictcomp>(.0)
# ----> 1 trn_lrg_ann = {a: get_lrg(b) for a,b in trn_anno.items()}
#
# <ipython-input-29-0e628c8db941> in get_lrg(b)
#       1 def get_lrg(b):
#       2     if not b: raise Exception()
# ----> 3     b = sorted(b, key=lambda x: np.product(x[0][-2:] - x[0[:2]]))
#       4     return b[0]
#
# <ipython-input-29-0e628c8db941> in <lambda>(x)
#       1 def get_lrg(b):
#       2     if not b: raise Exception()
# ----> 3     b = sorted(b, key=lambda x: np.product(x[0][-2:] - x[0[:2]]))
#       4     return b[0]
#
# TypeError: 'int' object is not subscriptable
